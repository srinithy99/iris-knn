# %%
 import pandas as pd 
import numpy as np  
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris_df = pd.read_csv('iris.csv')

# %%
iris_df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris_df.tail()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica

# %%
sns.scatterplot( x = 'SepalLengthCm', y = 'SepalWidthCm', hue = 'Species', data = iris_df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-68a32fb37f98> in <module>()
# ----> 1 sns.scatterplot( x = 'SepalLengthCm', y = 'SepalWidthCm', hue = 'Species', data = iris_df)
#
# AttributeError: module 'seaborn' has no attribute 'scatterplot'

# %%
sns.scatterplot(x = 'PetalLengthCm', y = 'PetalWidthCm', hue = 'Species', data = iris_df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-8d58fe17c60e> in <module>()
# ----> 1 sns.scatterplot(x = 'PetalLengthCm', y = 'PetalWidthCm', hue = 'Species', data = iris_df)
#
# AttributeError: module 'seaborn' has no attribute 'scatterplot'

# %%
plt.figure(figsize=(10,10))

plt.subplot(2,2,1)
sns.violinplot(x='Species',y='PetalLengthCm',data=iris_df)

plt.subplot(2,2,2)
sns.violinplot(x='Species',y='PetalWidthCm',data=iris_df)

plt.subplot(2,2,3)
sns.violinplot(x='Species',y='SepalLengthCm',data=iris_df)

plt.subplot(2,2,4)
sns.violinplot(x='Species',y='SepalWidthCm',data=iris_df)

# %%
sns.pairplot(iris_df, hue = 'Species')

# %%
plt.figure(figsize=(10,7)) 
sns.heatmap(iris_df.corr(),annot=True)

# %%
X = iris_df.drop(['Species'],axis=1)
X
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# 5              5.4           3.9            1.7           0.4
# 6              4.6           3.4            1.4           0.3
# 7              5.0           3.4            1.5           0.2
# 8              4.4           2.9            1.4           0.2
# 9              4.9           3.1            1.5           0.1
# 10             5.4           3.7            1.5           0.2
# 11             4.8           3.4            1.6           0.2
# 12             4.8           3.0            1.4           0.1
# 13             4.3           3.0            1.1           0.1
# 14             5.8           4.0            1.2           0.2
# 15             5.7           4.4            1.5           0.4
# 16             5.4           3.9            1.3           0.4
# 17             5.1           3.5            1.4           0.3
# 18             5.7           3.8            1.7           0.3
# 19             5.1           3.8            1.5           0.3
# 20             5.4           3.4            1.7           0.2
# 21             5.1           3.7            1.5           0.4
# 22             4.6           3.6            1.0           0.2
# 23             5.1           3.3            1.7           0.5
# 24             4.8           3.4            1.9           0.2
# 25             5.0           3.0            1.6           0.2
# 26             5.0           3.4            1.6           0.4
# 27             5.2           3.5            1.5           0.2
# 28             5.2           3.4            1.4           0.2
# 29             4.7           3.2            1.6           0.2
# ..             ...           ...            ...           ...
# 120            6.9           3.2            5.7           2.3
# 121            5.6           2.8            4.9           2.0
# 122            7.7           2.8            6.7           2.0
# 123            6.3           2.7            4.9           1.8
# 124            6.7           3.3            5.7           2.1
# 125            7.2           3.2            6.0           1.8
# 126            6.2           2.8            4.8           1.8
# 127            6.1           3.0            4.9           1.8
# 128            6.4           2.8            5.6           2.1
# 129            7.2           3.0            5.8           1.6
# 130            7.4           2.8            6.1           1.9
# 131            7.9           3.8            6.4           2.0
# 132            6.4           2.8            5.6           2.2
# 133            6.3           2.8            5.1           1.5
# 134            6.1           2.6            5.6           1.4
# 135            7.7           3.0            6.1           2.3
# 136            6.3           3.4            5.6           2.4
# 137            6.4           3.1            5.5           1.8
# 138            6.0           3.0            4.8           1.8
# 139            6.9           3.1            5.4           2.1
# 140            6.7           3.1            5.6           2.4
# 141            6.9           3.1            5.1           2.3
# 142            5.8           2.7            5.1           1.9
# 143            6.8           3.2            5.9           2.3
# 144            6.7           3.3            5.7           2.5
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %%
y = iris_df['Species']
y
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
# 5         Iris-setosa
# 6         Iris-setosa
# 7         Iris-setosa
# 8         Iris-setosa
# 9         Iris-setosa
# 10        Iris-setosa
# 11        Iris-setosa
# 12        Iris-setosa
# 13        Iris-setosa
# 14        Iris-setosa
# 15        Iris-setosa
# 16        Iris-setosa
# 17        Iris-setosa
# 18        Iris-setosa
# 19        Iris-setosa
# 20        Iris-setosa
# 21        Iris-setosa
# 22        Iris-setosa
# 23        Iris-setosa
# 24        Iris-setosa
# 25        Iris-setosa
# 26        Iris-setosa
# 27        Iris-setosa
# 28        Iris-setosa
# 29        Iris-setosa
#             ...
# 120    Iris-virginica
# 121    Iris-virginica
# 122    Iris-virginica
# 123    Iris-virginica
# 124    Iris-virginica
# 125    Iris-virginica
# 126    Iris-virginica
# 127    Iris-virginica
# 128    Iris-virginica
# 129    Iris-virginica
# 130    Iris-virginica
# 131    Iris-virginica
# 132    Iris-virginica
# 133    Iris-virginica
# 134    Iris-virginica
# 135    Iris-virginica
# 136    Iris-virginica
# 137    Iris-virginica
# 138    Iris-virginica
# 139    Iris-virginica
# 140    Iris-virginica
# 141    Iris-virginica
# 142    Iris-virginica
# 143    Iris-virginica
# 144    Iris-virginica
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species, Length: 150, dtype: object

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.35)

# %%
X_train.shape
# Out:
# (97, 4)

# %%
X_train.head()
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 32            5.2           4.1            1.5           0.1
# 36            5.5           3.5            1.3           0.2
# 43            5.0           3.5            1.6           0.6
# 83            6.0           2.7            5.1           1.6
# 58            6.6           2.9            4.6           1.3

# %%
y_train
# Out:
# 32         Iris-setosa
# 36         Iris-setosa
# 43         Iris-setosa
# 83     Iris-versicolor
# 58     Iris-versicolor
# 33         Iris-setosa
# 28         Iris-setosa
# 61     Iris-versicolor
# 107     Iris-virginica
# 49         Iris-setosa
# 76     Iris-versicolor
# 63     Iris-versicolor
# 7          Iris-setosa
# 38         Iris-setosa
# 90     Iris-versicolor
# 77     Iris-versicolor
# 4          Iris-setosa
# 147     Iris-virginica
# 135     Iris-virginica
# 91     Iris-versicolor
# 143     Iris-virginica
# 54     Iris-versicolor
# 67     Iris-versicolor
# 95     Iris-versicolor
# 113     Iris-virginica
# 123     Iris-virginica
# 41         Iris-setosa
# 14         Iris-setosa
# 108     Iris-virginica
# 104     Iris-virginica
#             ...
# 129     Iris-virginica
# 59     Iris-versicolor
# 3          Iris-setosa
# 72     Iris-versicolor
# 116     Iris-virginica
# 55     Iris-versicolor
# 82     Iris-versicolor
# 23         Iris-setosa
# 100     Iris-virginica
# 109     Iris-virginica
# 138     Iris-virginica
# 122     Iris-virginica
# 98     Iris-versicolor
# 121     Iris-virginica
# 45         Iris-setosa
# 19         Iris-setosa
# 65     Iris-versicolor
# 8          Iris-setosa
# 25         Iris-setosa
# 106     Iris-virginica
# 148     Iris-virginica
# 75     Iris-versicolor
# 21         Iris-setosa
# 74     Iris-versicolor
# 29         Iris-setosa
# 48         Iris-setosa
# 39         Iris-setosa
# 22         Iris-setosa
# 56     Iris-versicolor
# 60     Iris-versicolor
# Name: Species, Length: 97, dtype: object

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, confusion_matrix

classifier = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)
classifier.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform')

# %%
y_predict = classifier.predict(X_test)
cm = confusion_matrix(y_test, y_predict)
sns.heatmap(cm, annot=True, fmt="d")

# %%
print(classification_report(y_test, y_predict))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        13
# Iris-versicolor       1.00      1.00      1.00        19
#  Iris-virginica       1.00      1.00      1.00        21
#
#     avg / total       1.00      1.00      1.00        53
